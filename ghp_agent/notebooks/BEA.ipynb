# %%
import logging
import requests
import json
import os
from google.cloud import logging as google_cloud_logging
logging_client = google_cloud_logging.Client()
logger = logging_client.logger(__name__)
os.environ['BEA_API_KEY'] = "28985005-6B78-4B26-9C10-455260B953E3"

def get_bea_gdp(place_fips, year='2023',url="https://apps.bea.gov/api/data/"):

    params = {
            'UserID': os.environ['BEA_API_KEY'],
            'method': 'GetData',
            'DataSetName': 'Regional',
            'TableName':'CAGDP2',
            'LineCode': '1',
            'GeoFips': place_fips,
            'Year': year
    }
    
    try:
        response = requests.get(url, params=params)
        data = json.loads(response.content)
        response_value = data['BEAAPI']['Results']['Data']
    except Exception as e:
        logging.error("Failed to fetch GDP By Metropolitan", str(e))

    return response_value

# %%
response_value = get_bea_gdp('12086')
response_value
# Out:
# [{'Code': 'CAGDP2-1',
#   'GeoFips': '12086',
#   'GeoName': 'Miami-Dade',
#   'TimePeriod': '2023',
#   'CL_UNIT': 'Thousands of dollars',
#   'UNIT_MULT': '3',
#   'DataValue': '239652386'}]

# %%
data['BEAAPI']['Results']['Data']
# Out:
# [{'Code': 'CAGDP2-1',
#   'GeoFips': '12086',
#   'GeoName': 'Miami-Dade',
#   'TimePeriod': '2023',
#   'CL_UNIT': 'Thousands of dollars',
#   'UNIT_MULT': '3',
#   'DataValue': '239652386'}]

# %%
# os.environ["BEA_API_KEY"] = "28985005-6B78-4B26-9C10-455260B953E3"

# %%
PROJECT_ID = "ghp-poc"
REGION = "us-central1"

# %% [markdown]
# ### Dependency Imports

# %%
from typing import Optional

import pydantic 
import pandas as pd
# from thefuzz import fuzz
from google import genai
from google.genai import types as genai_types
from google.cloud import bigquery

from census import Census
from us import states
import requests

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Initialize Clients

# %%
bq_client = bigquery.Client(project=PROJECT_ID)
genai_client = genai.Client(vertexai=True, project=PROJECT_ID, location=REGION)

# %%
BEA_API_KEY="28985005-6B78-4B26-9C10-455260B953E3"

# %%
CENSUS_API_KEY = ""
c = Census(CENSUS_API_KEY)

# %%
def get_state_fips(state_name):
    url = "https://api.census.gov/data/2021/pep/population?get=NAME,STATE&for=state:*"
    response = requests.get(url)
    data = response.json()

    for row in data[1:]:  # Skip header row
        if row[0].lower() == state_name.lower():
            return row[1]  # Return the state FIPS code
    return None

def get_place_fips(city_name, state_fips):
    places = c.acs1.get(["NAME"], {'for': 'place:*', 'in': f'state:{state_fips}'})
    
    for place in places:
        if city_name.lower() in place["NAME"].lower():
            return place["place"]
    return None

# %%
city_name = 'Houston'
state_name = 'Texas'
state_fips = get_state_fips(state_name)
place_fips = get_place_fips(city_name, state_fips)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 3
#       1 city_name = 'Houston'
#       2 state_name = 'Texas'
# ----> 3 state_fips = get_state_fips(state_name)
#       4 place_fips = get_place_fips(city_name, state_fips)
#
# Cell In[47], line 3, in get_state_fips(state_name)
#       1 def get_state_fips(state_name):
#       2     url = "https://api.census.gov/data/2021/pep/population?get=NAME,STATE&for=state:*"
# ----> 3     response = requests.get(url)
#       4     data = response.json()
#       6     for row in data[1:]:  # Skip header row
#
# File ~/ghp_new/gph_chatbot_poc/ghp_agent/.localenv/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/ghp_new/gph_chatbot_poc/ghp_agent/.localenv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/ghp_new/gph_chatbot_poc/ghp_agent/.localenv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/ghp_new/gph_chatbot_poc/ghp_agent/.localenv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/ghp_new/gph_chatbot_poc/ghp_agent/.localenv/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/ghp_new/gph_chatbot_poc/ghp_agent/.localenv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/ghp_new/gph_chatbot_poc/ghp_agent/.localenv/lib/python3.13/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/ghp_new/gph_chatbot_poc/ghp_agent/.localenv/lib/python3.13/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/ghp_new/gph_chatbot_poc/ghp_agent/.localenv/lib/python3.13/site-packages/urllib3/connection.py:704, in HTTPSConnection.connect(self)
#     702 try:
#     703     sock: socket.socket | ssl.SSLSocket
# --> 704     self.sock = sock = self._new_conn()
#     705     server_hostname: str = self.host
#     706     tls_in_tls = False
#
# File ~/ghp_new/gph_chatbot_poc/ghp_agent/.localenv/lib/python3.13/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File ~/ghp_new/gph_chatbot_poc/ghp_agent/.localenv/lib/python3.13/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
state_fips,place_fips
# Out:
# ('48', '35000')

# %%
DATASET_URL = f'https://apps.bea.gov/api/data?&UserID={BEA_API_KEY}&method=GETDATASETLIST&'
response = requests.get(DATASET_URL)
response.content
# Out:
# b'{"BEAAPI":{"Request":{"RequestParam":[{"ParameterName":"USERID","ParameterValue":"28985005-6B78-4B26-9C10-455260B953E3"},{"ParameterName":"METHOD","ParameterValue":"GETDATASETLIST"},{"ParameterName":"RESULTFORMAT","ParameterValue":"JSON"}]},"Results":{"Dataset":[{"DatasetName":"NIPA","DatasetDescription":"Standard NIPA tables"},{"DatasetName":"NIUnderlyingDetail","DatasetDescription":"Standard NI underlying detail tables"},{"DatasetName":"MNE","DatasetDescription":"Multinational Enterprises"},{"DatasetName":"FixedAssets","DatasetDescription":"Standard Fixed Assets tables"},{"DatasetName":"ITA","DatasetDescription":"International Transactions Accounts"},{"DatasetName":"IIP","DatasetDescription":"International Investment Position"},{"DatasetName":"InputOutput","DatasetDescription":"Input-Output Data"},{"DatasetName":"IntlServTrade","DatasetDescription":"International Services Trade"},{"DatasetName":"IntlServSTA","DatasetDescription":"International Services Supplied Through Affiliates"},{"DatasetName":"GDPbyIndustry","DatasetDescription":"GDP by Industry"},{"DatasetName":"Regional","DatasetDescription":"Regional data sets"},{"DatasetName":"UnderlyingGDPbyIndustry","DatasetDescription":"Underlying GDP by Industry"},{"DatasetName":"APIDatasetMetaData","DatasetDescription":"Metadata about other API datasets"}]}}}'

# %%
import json

# %%
REGIONAL_URL=f"https://apps.bea.gov/api/data/?&UserID={BEA_API_KEY}&method=GetData&DataSetName=Regional&TableName=CAGDP2&LineCode=1&GeoFips=MSA&Year=2023"
response = requests.get(REGIONAL_URL)
json.loads(response.content)
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'USERID',
#      'ParameterValue': '28985005-6B78-4B26-9C10-455260B953E3'},
#     {'ParameterName': 'METHOD', 'ParameterValue': 'GETDATA'},
#     {'ParameterName': 'DATASETNAME', 'ParameterValue': 'REGIONAL'},
#     {'ParameterName': 'TABLENAME', 'ParameterValue': 'CAGDP2'},
#     {'ParameterName': 'LINECODE', 'ParameterValue': '1'},
#     {'ParameterName': 'GEOFIPS', 'ParameterValue': 'MSA'},
#     {'ParameterName': 'YEAR', 'ParameterValue': '2023'},
#     {'ParameterName': 'RESULTFORMAT', 'ParameterValue': 'JSON'}]},
#   'Results': {'Statistic': 'Gross Domestic Product (GDP): All industry total',
#    'UnitOfMeasure': 'Thousands of dollars',
#    'PublicTable': 'CAGDP2 Gross domestic product (GDP) by county and metropolitan area',
#    'UTCProductionTime': '2025-03-24T11:04:52.857',
#    'NoteRef': ' ',
#    'Dimensions': [{'Name': 'Code', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'GeoFips', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'GeoName', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'TimePeriod', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'DataValue', 'DataType': 'numeric', 'IsValue': '1'},
#     {'Name': 'CL_UNIT', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'UNIT_MULT', 'DataType': 'numeric', 'IsValue': '0'}],
#    'Data': [{'Code': 'CAGDP2-1',
#      'GeoFips': '00998',
#      'GeoName': 'United States (Metropolitan Portion) *',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '24910942346',
#      'NoteRef': '*'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '10180',
#      'GeoName': 'Abilene, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '10306623'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '10420',
#      'GeoName': 'Akron, OH (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '47285487'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '10500',
#      'GeoName': 'Albany, GA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7782093'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '10540',
#      'GeoName': 'Albany-Lebanon, OR (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6441520'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '10580',
#      'GeoName': 'Albany-Schenectady-Troy, NY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '84910398'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '10740',
#      'GeoName': 'Albuquerque, NM (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '59382941'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '10780',
#      'GeoName': 'Alexandria, LA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7753574'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '10900',
#      'GeoName': 'Allentown-Bethlehem-Easton, PA-NJ (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '59890990'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '11020',
#      'GeoName': 'Altoona, PA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7681160'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '11100',
#      'GeoName': 'Amarillo, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '18913682'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '11180',
#      'GeoName': 'Ames, IA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8615031'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '11260',
#      'GeoName': 'Anchorage, AK (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '34065381'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '11460',
#      'GeoName': 'Ann Arbor, MI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '33013856'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '11500',
#      'GeoName': 'Anniston-Oxford, AL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '5891059'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '11540',
#      'GeoName': 'Appleton, WI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '18532326'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '11700',
#      'GeoName': 'Asheville, NC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '29014297'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '12020',
#      'GeoName': 'Athens-Clarke County, GA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '13768348'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '12060',
#      'GeoName': 'Atlanta-Sandy Springs-Alpharetta, GA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '570662834'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '12100',
#      'GeoName': 'Atlantic City-Hammonton, NJ (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '18726628'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '12220',
#      'GeoName': 'Auburn-Opelika, AL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8799349'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '12260',
#      'GeoName': 'Augusta-Richmond County, GA-SC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '37292712'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '12420',
#      'GeoName': 'Austin-Round Rock-Georgetown, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '248109564'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '12540',
#      'GeoName': 'Bakersfield, CA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '59846810'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '12580',
#      'GeoName': 'Baltimore-Columbia-Towson, MD (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '259690214'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '12620',
#      'GeoName': 'Bangor, ME (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9020616'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '12700',
#      'GeoName': 'Barnstable Town, MA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '18186673'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '12940',
#      'GeoName': 'Baton Rouge, LA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '68827180'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '12980',
#      'GeoName': 'Battle Creek, MI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8543282'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '13020',
#      'GeoName': 'Bay City, MI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '4507259'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '13140',
#      'GeoName': 'Beaumont-Port Arthur, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '31114626'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '13220',
#      'GeoName': 'Beckley, WV (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '5541536'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '13380',
#      'GeoName': 'Bellingham, WA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '21489731'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '13460',
#      'GeoName': 'Bend, OR (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '15445974'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '13740',
#      'GeoName': 'Billings, MT (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '14407832'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '13780',
#      'GeoName': 'Binghamton, NY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '12927169'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '13820',
#      'GeoName': 'Birmingham-Hoover, AL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '84566170'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '13900',
#      'GeoName': 'Bismarck, ND (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9430711'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '13980',
#      'GeoName': 'Blacksburg-Christiansburg, VA (Metropolitan Statistical Area) *',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '10166304',
#      'NoteRef': '*'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '14010',
#      'GeoName': 'Bloomington, IL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '15005648'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '14020',
#      'GeoName': 'Bloomington, IN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9641723'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '14100',
#      'GeoName': 'Bloomsburg-Berwick, PA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '5613010'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '14260',
#      'GeoName': 'Boise City, ID (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '55331136'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '14460',
#      'GeoName': 'Boston-Cambridge-Newton, MA-NH (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '610486075'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '14500',
#      'GeoName': 'Boulder, CO (Metropolitan Statistical Area) *',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '37662897',
#      'NoteRef': '*'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '14540',
#      'GeoName': 'Bowling Green, KY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '11830435'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '14740',
#      'GeoName': 'Bremerton-Silverdale-Port Orchard, WA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '17319445'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '14860',
#      'GeoName': 'Bridgeport-Stamford-Norwalk, CT (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '116030979'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '15180',
#      'GeoName': 'Brownsville-Harlingen, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '15602248'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '15260',
#      'GeoName': 'Brunswick, GA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6444126'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '15380',
#      'GeoName': 'Buffalo-Cheektowaga, NY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '90716457'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '15500',
#      'GeoName': 'Burlington, NC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8624438'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '15540',
#      'GeoName': 'Burlington-South Burlington, VT (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '18671208'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '15680',
#      'GeoName': 'California-Lexington Park, MD (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9882630'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '15940',
#      'GeoName': 'Canton-Massillon, OH (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '24599897'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '15980',
#      'GeoName': 'Cape Coral-Fort Myers, FL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '50645899'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16020',
#      'GeoName': 'Cape Girardeau, MO-IL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '5797295'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16060',
#      'GeoName': 'Carbondale-Marion, IL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7263128'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16180',
#      'GeoName': 'Carson City, NV (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '4777092'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16220',
#      'GeoName': 'Casper, WY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6983637'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16300',
#      'GeoName': 'Cedar Rapids, IA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '22962630'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16540',
#      'GeoName': 'Chambersburg-Waynesboro, PA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8148840'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16580',
#      'GeoName': 'Champaign-Urbana, IL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '15512304'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16620',
#      'GeoName': 'Charleston, WV (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '16291494'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16700',
#      'GeoName': 'Charleston-North Charleston, SC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '63973949'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16740',
#      'GeoName': 'Charlotte-Concord-Gastonia, NC-SC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '255666417'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16820',
#      'GeoName': 'Charlottesville, VA (Metropolitan Statistical Area) *',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '18817343',
#      'NoteRef': '*'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16860',
#      'GeoName': 'Chattanooga, TN-GA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '42381201'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16940',
#      'GeoName': 'Cheyenne, WY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8285241'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '16980',
#      'GeoName': 'Chicago-Naperville-Elgin, IL-IN-WI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '894862364'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '17020',
#      'GeoName': 'Chico, CA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '11727399'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '17140',
#      'GeoName': 'Cincinnati, OH-KY-IN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '198888723'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '17300',
#      'GeoName': 'Clarksville, TN-KY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '17765745'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '17420',
#      'GeoName': 'Cleveland, TN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6807509'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '17460',
#      'GeoName': 'Cleveland-Elyria, OH (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '173135607'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '17660',
#      'GeoName': "Coeur d'Alene, ID (Metropolitan Statistical Area)",
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '10583848'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '17780',
#      'GeoName': 'College Station-Bryan, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '19585335'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '17820',
#      'GeoName': 'Colorado Springs, CO (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '53092641'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '17860',
#      'GeoName': 'Columbia, MO (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '13572357'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '17900',
#      'GeoName': 'Columbia, SC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '58497422'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '17980',
#      'GeoName': 'Columbus, GA-AL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '18710583'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '18020',
#      'GeoName': 'Columbus, IN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8668346'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '18140',
#      'GeoName': 'Columbus, OH (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '182087631'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '18580',
#      'GeoName': 'Corpus Christi, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '30930920'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '18700',
#      'GeoName': 'Corvallis, OR (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6035305'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '18880',
#      'GeoName': 'Crestview-Fort Walton Beach-Destin, FL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '23794720'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '19060',
#      'GeoName': 'Cumberland, MD-WV (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '4359585'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '19100',
#      'GeoName': 'Dallas-Fort Worth-Arlington, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '744653629'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '19140',
#      'GeoName': 'Dalton, GA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9271266'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '19180',
#      'GeoName': 'Danville, IL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '4136523'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '19300',
#      'GeoName': 'Daphne-Fairhope-Foley, AL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '12071468'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '19340',
#      'GeoName': 'Davenport-Moline-Rock Island, IA-IL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '27875132'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '19430',
#      'GeoName': 'Dayton-Kettering, OH (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '57479376'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '19460',
#      'GeoName': 'Decatur, AL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8841158'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '19500',
#      'GeoName': 'Decatur, IL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8822934'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '19660',
#      'GeoName': 'Deltona-Daytona Beach-Ormond Beach, FL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '32539529'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '19740',
#      'GeoName': 'Denver-Aurora-Lakewood, CO (Metropolitan Statistical Area) *',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '311876352',
#      'NoteRef': '*'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '19780',
#      'GeoName': 'Des Moines-West Des Moines, IA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '74062506'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '19820',
#      'GeoName': 'Detroit-Warren-Dearborn, MI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '331333163'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '20020',
#      'GeoName': 'Dothan, AL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9099360'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '20100',
#      'GeoName': 'Dover, DE (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '10509748'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '20220',
#      'GeoName': 'Dubuque, IA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9017369'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '20260',
#      'GeoName': 'Duluth, MN-WI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '18838611'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '20500',
#      'GeoName': 'Durham-Chapel Hill, NC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '70305292'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '20700',
#      'GeoName': 'East Stroudsburg, PA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9215416'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '20740',
#      'GeoName': 'Eau Claire, WI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '11674198'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '20940',
#      'GeoName': 'El Centro, CA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '13483299'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '21060',
#      'GeoName': 'Elizabethtown-Fort Knox, KY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8182312'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '21140',
#      'GeoName': 'Elkhart-Goshen, IN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '20857760'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '21300',
#      'GeoName': 'Elmira, NY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '4544209'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '21340',
#      'GeoName': 'El Paso, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '48609163'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '21420',
#      'GeoName': 'Enid, OK (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '3804621'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '21500',
#      'GeoName': 'Erie, PA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '14204975'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '21660',
#      'GeoName': 'Eugene-Springfield, OR (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '22550913'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '21780',
#      'GeoName': 'Evansville, IN-KY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '27437679'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '21820',
#      'GeoName': 'Fairbanks, AK (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7198784'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '22020',
#      'GeoName': 'Fargo, ND-MN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '20535575'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '22140',
#      'GeoName': 'Farmington, NM (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6822347'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '22180',
#      'GeoName': 'Fayetteville, NC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '28205160'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '22220',
#      'GeoName': 'Fayetteville-Springdale-Rogers, AR (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '40776485'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '22380',
#      'GeoName': 'Flagstaff, AZ (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9967529'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '22420',
#      'GeoName': 'Flint, MI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '19151079'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '22500',
#      'GeoName': 'Florence, SC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '12505628'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '22520',
#      'GeoName': 'Florence-Muscle Shoals, AL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7212666'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '22540',
#      'GeoName': 'Fond du Lac, WI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6451530'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '22660',
#      'GeoName': 'Fort Collins, CO (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '26974178'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '22900',
#      'GeoName': 'Fort Smith, AR-OK (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '12729594'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '23060',
#      'GeoName': 'Fort Wayne, IN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '30231008'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '23420',
#      'GeoName': 'Fresno, CA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '60151259'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '23460',
#      'GeoName': 'Gadsden, AL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '3776967'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '23540',
#      'GeoName': 'Gainesville, FL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '21823778'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '23580',
#      'GeoName': 'Gainesville, GA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '16640845'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '23900',
#      'GeoName': 'Gettysburg, PA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '4739846'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '24020',
#      'GeoName': 'Glens Falls, NY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8717091'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '24140',
#      'GeoName': 'Goldsboro, NC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6339867'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '24220',
#      'GeoName': 'Grand Forks, ND-MN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6878157'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '24260',
#      'GeoName': 'Grand Island, NE (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '5979384'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '24300',
#      'GeoName': 'Grand Junction, CO (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9147468'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '24340',
#      'GeoName': 'Grand Rapids-Kentwood, MI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '82311400'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '24420',
#      'GeoName': 'Grants Pass, OR (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '3877152'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '24500',
#      'GeoName': 'Great Falls, MT (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '5345805'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '24540',
#      'GeoName': 'Greeley, CO (Metropolitan Statistical Area) *',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '28181144',
#      'NoteRef': '*'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '24580',
#      'GeoName': 'Green Bay, WI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '26276686'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '24660',
#      'GeoName': 'Greensboro-High Point, NC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '52925956'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '24780',
#      'GeoName': 'Greenville, NC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '11865912'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '24860',
#      'GeoName': 'Greenville-Anderson, SC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '63357431'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '25060',
#      'GeoName': 'Gulfport-Biloxi, MS (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '24668587'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '25180',
#      'GeoName': 'Hagerstown-Martinsburg, MD-WV (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '15286099'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '25220',
#      'GeoName': 'Hammond, LA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6219912'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '25260',
#      'GeoName': 'Hanford-Corcoran, CA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8873931'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '25420',
#      'GeoName': 'Harrisburg-Carlisle, PA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '50902418'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '25500',
#      'GeoName': 'Harrisonburg, VA (Metropolitan Statistical Area) *',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '10348301',
#      'NoteRef': '*'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '25540',
#      'GeoName': 'Hartford-East Hartford-Middletown, CT (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '122805302'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '25620',
#      'GeoName': 'Hattiesburg, MS (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8700243'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '25860',
#      'GeoName': 'Hickory-Lenoir-Morganton, NC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '19612987'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '25940',
#      'GeoName': 'Hilton Head Island-Bluffton, SC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '14360798'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '25980',
#      'GeoName': 'Hinesville, GA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '5154740'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '26140',
#      'GeoName': 'Homosassa Springs, FL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6430594'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '26300',
#      'GeoName': 'Hot Springs, AR (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '4606197'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '26380',
#      'GeoName': 'Houma-Thibodaux, LA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '12215010'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '26420',
#      'GeoName': 'Houston-The Woodlands-Sugar Land, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '696999366'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '26580',
#      'GeoName': 'Huntington-Ashland, WV-KY-OH (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '19176990'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '26620',
#      'GeoName': 'Huntsville, AL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '42815938'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '26820',
#      'GeoName': 'Idaho Falls, ID (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '11962936'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '26900',
#      'GeoName': 'Indianapolis-Carmel-Anderson, IN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '199197977'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '26980',
#      'GeoName': 'Iowa City, IA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '13602212'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '27060',
#      'GeoName': 'Ithaca, NY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7388818'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '27100',
#      'GeoName': 'Jackson, MI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8588193'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '27140',
#      'GeoName': 'Jackson, MS (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '37054502'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '27180',
#      'GeoName': 'Jackson, TN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '11474534'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '27260',
#      'GeoName': 'Jacksonville, FL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '129094522'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '27340',
#      'GeoName': 'Jacksonville, NC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '11858614'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '27500',
#      'GeoName': 'Janesville-Beloit, WI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '10503232'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '27620',
#      'GeoName': 'Jefferson City, MO (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '10722699'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '27740',
#      'GeoName': 'Johnson City, TN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '10758069'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '27780',
#      'GeoName': 'Johnstown, PA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6068733'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '27860',
#      'GeoName': 'Jonesboro, AR (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7875673'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '27900',
#      'GeoName': 'Joplin, MO (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9860195'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '27980',
#      'GeoName': 'Kahului-Wailuku-Lahaina, HI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '12299263'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '28020',
#      'GeoName': 'Kalamazoo-Portage, MI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '20316132'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '28100',
#      'GeoName': 'Kankakee, IL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8725053'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '28140',
#      'GeoName': 'Kansas City, MO-KS (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '185746211'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '28420',
#      'GeoName': 'Kennewick-Richland, WA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '21082419'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '28660',
#      'GeoName': 'Killeen-Temple, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '26667324'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '28700',
#      'GeoName': 'Kingsport-Bristol, TN-VA (Metropolitan Statistical Area) *',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '18326336',
#      'NoteRef': '*'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '28740',
#      'GeoName': 'Kingston, NY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9905383'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '28940',
#      'GeoName': 'Knoxville, TN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '64382649'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '29020',
#      'GeoName': 'Kokomo, IN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '5473566'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '29100',
#      'GeoName': 'La Crosse-Onalaska, WI-MN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '10146203'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '29180',
#      'GeoName': 'Lafayette, LA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '27687065'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '29200',
#      'GeoName': 'Lafayette-West Lafayette, IN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '14979052'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '29340',
#      'GeoName': 'Lake Charles, LA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '19707364'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '29420',
#      'GeoName': 'Lake Havasu City-Kingman, AZ (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
# ...
#      'GeoName': 'Sheboygan, WI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8738603'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '43300',
#      'GeoName': 'Sherman-Denison, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7289716'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '43340',
#      'GeoName': 'Shreveport-Bossier City, LA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '27913122'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '43420',
#      'GeoName': 'Sierra Vista-Douglas, AZ (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6080882'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '43580',
#      'GeoName': 'Sioux City, IA-NE-SD (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '11978474'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '43620',
#      'GeoName': 'Sioux Falls, SD (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '30084975'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '43780',
#      'GeoName': 'South Bend-Mishawaka, IN-MI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '20547790'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '43900',
#      'GeoName': 'Spartanburg, SC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '21159577'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '44060',
#      'GeoName': 'Spokane-Spokane Valley, WA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '39735793'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '44100',
#      'GeoName': 'Springfield, IL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '14899178'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '44140',
#      'GeoName': 'Springfield, MA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '42356150'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '44180',
#      'GeoName': 'Springfield, MO (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '28577385'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '44220',
#      'GeoName': 'Springfield, OH (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '5909466'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '44300',
#      'GeoName': 'State College, PA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '10952214'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '44420',
#      'GeoName': 'Staunton, VA (Metropolitan Statistical Area) *',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6760948',
#      'NoteRef': '*'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '44700',
#      'GeoName': 'Stockton, CA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '42836031'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '44940',
#      'GeoName': 'Sumter, SC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6599335'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '45060',
#      'GeoName': 'Syracuse, NY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '51191017'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '45220',
#      'GeoName': 'Tallahassee, FL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '24529748'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '45300',
#      'GeoName': 'Tampa-St. Petersburg-Clearwater, FL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '243268344'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '45460',
#      'GeoName': 'Terre Haute, IN (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '10300542'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '45500',
#      'GeoName': 'Texarkana, TX-AR (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7215096'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '45540',
#      'GeoName': 'The Villages, FL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7137460'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '45780',
#      'GeoName': 'Toledo, OH (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '49254628'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '45820',
#      'GeoName': 'Topeka, KS (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '15156457'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '45940',
#      'GeoName': 'Trenton-Princeton, NJ (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '53002639'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '46060',
#      'GeoName': 'Tucson, AZ (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '62169929'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '46140',
#      'GeoName': 'Tulsa, OK (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '67510846'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '46220',
#      'GeoName': 'Tuscaloosa, AL (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '14767427'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '46300',
#      'GeoName': 'Twin Falls, ID (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7542028'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '46340',
#      'GeoName': 'Tyler, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '15683898'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '46520',
#      'GeoName': 'Urban Honolulu, HI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '81675550'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '46540',
#      'GeoName': 'Utica-Rome, NY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '16282294'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '46660',
#      'GeoName': 'Valdosta, GA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7679252'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '46700',
#      'GeoName': 'Vallejo, CA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '37156243'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '47020',
#      'GeoName': 'Victoria, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '6323208'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '47220',
#      'GeoName': 'Vineland-Bridgeton, NJ (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8208721'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '47260',
#      'GeoName': 'Virginia Beach-Norfolk-Newport News, VA-NC (Metropolitan Statistical Area) *',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '127459149',
#      'NoteRef': '*'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '47300',
#      'GeoName': 'Visalia, CA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '24256732'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '47380',
#      'GeoName': 'Waco, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '18135219'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '47460',
#      'GeoName': 'Walla Walla, WA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '4362362'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '47580',
#      'GeoName': 'Warner Robins, GA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '10549159'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '47900',
#      'GeoName': 'Washington-Arlington-Alexandria, DC-VA-MD-WV (Metropolitan Statistical Area) *',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '714685087',
#      'NoteRef': '*'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '47940',
#      'GeoName': 'Waterloo-Cedar Falls, IA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '12521946'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '48060',
#      'GeoName': 'Watertown-Fort Drum, NY (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8037177'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '48140',
#      'GeoName': 'Wausau-Weston, WI (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '12711703'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '48260',
#      'GeoName': 'Weirton-Steubenville, WV-OH (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7568043'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '48300',
#      'GeoName': 'Wenatchee, WA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9343442'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '48540',
#      'GeoName': 'Wheeling, WV-OH (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '12658006'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '48620',
#      'GeoName': 'Wichita, KS (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '46468045'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '48660',
#      'GeoName': 'Wichita Falls, TX (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '8256094'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '48700',
#      'GeoName': 'Williamsport, PA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '7486729'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '48900',
#      'GeoName': 'Wilmington, NC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '21996036'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '49020',
#      'GeoName': 'Winchester, VA-WV (Metropolitan Statistical Area) *',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9988848',
#      'NoteRef': '*'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '49180',
#      'GeoName': 'Winston-Salem, NC (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '44750605'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '49340',
#      'GeoName': 'Worcester, MA-CT (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '64135380'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '49420',
#      'GeoName': 'Yakima, WA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '13357488'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '49620',
#      'GeoName': 'York-Hanover, PA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '27867147'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '49660',
#      'GeoName': 'Youngstown-Warren-Boardman, OH-PA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '26178157'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '49700',
#      'GeoName': 'Yuba City, CA (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '9225272'},
#     {'Code': 'CAGDP2-1',
#      'GeoFips': '49740',
#      'GeoName': 'Yuma, AZ (Metropolitan Statistical Area)',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '10584673'}],
#    'Notes': [{'NoteRef': '*',
#      'NoteText': 'Broomfield County, CO, was created from parts of Adams, Boulder, Jefferson, and Weld counties effective November 15, 2001. Estimates for Broomfield county begin with 2002.'},
#     {'NoteRef': '*',
#      'NoteText': 'Virginia combination areas consist of one or two independent cities with 1980 populations of less than 100,000 combined with an adjacent county. The county name appears first, followed by the city name(s). Separate estimates for the jurisdictions making up the combination area are not available. Bedford County, VA includes the independent city of Bedford for all years.'},
#     {'NoteRef': ' ',
#      'NoteText': 'Metropolitan Areas are defined (geographically delineated) by the Office of Management and Budget (OMB) bulletin no. 20-01 issued March 6, 2020.'},
#     {'NoteRef': '*',
#      'NoteText': 'For the All industry total and Government and government enterprises, the difference between the United States and Metropolitan and Nonmetropolitan portions reflects overseas activity, economic activity taking place outside the borders of the United States by the military and associated federal civilian support staff.'},
#     {'NoteRef': ' ',
#      'NoteText': 'Last updated: December 4, 2024-- new statistics for 2023; revised statistics for 2019-2022.'}]}}}

# %%
f"https://apps.bea.gov/api/data/?&UserID={BEA_API_KEY}&method=GetData&DataSetName=Regional&TableName=CAGDP2&LineCode=1&GeoFips={place_fips}&Year=2023&ResultFormat=XML"
# Out:
# 'https://apps.bea.gov/api/data/?&UserID=28985005-6B78-4B26-9C10-455260B953E3&method=GetData&DataSetName=Regional&TableName=CAGDP2&LineCode=1&GeoFips=35000&Year=2023&ResultFormat=XML'

# %%
place_fips = '12086'

# %%
DATA_URL=f"https://apps.bea.gov/api/data/?&UserID={BEA_API_KEY}&method=GetData&DataSetName=Regional&TableName=CAGDP2&LineCode=1&GeoFips={place_fips}&Year=2023"
response = requests.get(DATA_URL)
json.loads(response.content)
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'USERID',
#      'ParameterValue': '28985005-6B78-4B26-9C10-455260B953E3'},
#     {'ParameterName': 'METHOD', 'ParameterValue': 'GETDATA'},
#     {'ParameterName': 'DATASETNAME', 'ParameterValue': 'REGIONAL'},
#     {'ParameterName': 'TABLENAME', 'ParameterValue': 'CAGDP2'},
#     {'ParameterName': 'LINECODE', 'ParameterValue': '1'},
#     {'ParameterName': 'GEOFIPS', 'ParameterValue': '12086'},
#     {'ParameterName': 'YEAR', 'ParameterValue': '2023'},
#     {'ParameterName': 'RESULTFORMAT', 'ParameterValue': 'JSON'}]},
#   'Results': {'Statistic': 'Gross Domestic Product (GDP): All industry total',
#    'UnitOfMeasure': 'Thousands of dollars',
#    'PublicTable': 'CAGDP2 Gross domestic product (GDP) by county and metropolitan area',
#    'UTCProductionTime': '2025-03-24T13:56:42.317',
#    'NoteRef': ' ',
#    'Dimensions': [{'Name': 'Code', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'GeoFips', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'GeoName', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'TimePeriod', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'DataValue', 'DataType': 'numeric', 'IsValue': '1'},
#     {'Name': 'CL_UNIT', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 'UNIT_MULT', 'DataType': 'numeric', 'IsValue': '0'}],
#    'Data': [{'Code': 'CAGDP2-1',
#      'GeoFips': '12086',
#      'GeoName': 'Miami-Dade',
#      'TimePeriod': '2023',
#      'CL_UNIT': 'Thousands of dollars',
#      'UNIT_MULT': '3',
#      'DataValue': '239652386'}],
#    'Notes': [{'NoteRef': ' ',
#      'NoteText': 'Metropolitan Areas are defined (geographically delineated) by the Office of Management and Budget (OMB) bulletin no. 20-01 issued March 6, 2020.'},
#     {'NoteRef': ' ',
#      'NoteText': 'Last updated: December 4, 2024-- new statistics for 2023; revised statistics for 2019-2022.'}]}}}

# %%
c.acs.get(('NAME', 'B25034_010E'), {'for': 'state:%s' % states.MD.fips})
# Out:
# [{'NAME': 'Maryland', 'B25034_010E': 129032.0, 'state': '24'}]

# %%
# Function to get city population
def get_city_population(city_name:str,
                         state_name:str) -> float:
    """Fetches the population for the given city_name and state_name from census API
        
    Args:
        city_name (str): The name of the city.
        state_name (str): The name of the state. 
        If state_name is not mentioned specifically in the user query then infer it from knowledge

    Returns:
        float: population
    """
    print(f"called get_city_population with city_name={city_name}, state_name={state_name}")
    state_fips = get_state_fips(state_name)
    if not state_fips:
        print(f"State '{state_name}' not found.")
        return

    place_fips = get_place_fips(city_name, state_fips)
    if not place_fips:
        print(f"City '{city_name}' not found in {state_name}.")
        return

    # Fetch population
    population_variable = "B01003_001E"  # Total population
    result = c.acs1.get((population_variable, "NAME"), {'for': f'place:{place_fips}', 'in': f'state:{state_fips}'})
    
    if result:
        city_full_name = result[0]["NAME"]
        population = result[0][population_variable]
        # print(f"Population of {city_full_name}: {population}")
        return population
    else:
        return 0
        print("No data found.")

# %%
def get_state_fips(state_name):
    url = "https://api.census.gov/data/2021/pep/population?get=NAME,STATE&for=state:*"
    response = requests.get(url)
    data = response.json()

    for row in data[1:]:  # Skip header row
        if row[0].lower() == state_name.lower():
            return row[1]  # Return the state FIPS code
    return None

def get_place_fips(city_name, state_fips):
    places = c.acs1.get(["NAME"], {'for': 'place:*', 'in': f'state:{state_fips}'})
    
    for place in places:
        if city_name.lower() in place["NAME"].lower():
            return place["place"]
    return None

def get_city_statistics(city_name: str, state_name: str):
    """Fetches various statistics for the given city_name and state_name from Census API"""
    """
Median Age: "B01002_001E"
Total population 25+ yrs: "B15003_001E"
Percent Foreign Born: "B05012_003E" (Foreign-born population) / "B01003_001E" (Total population)
Percent Earned Bachelor's Degree or Higher (25 yrs and over), 2023: "B15003_022E", "B15003_023E", "B15003_024E", "B15003_025E" (Sum of these categories) / "B15003_001E"
Percent Earned Graduate or Professional Degree (25 yrs and over), 2023: "B15003_024E" (Master's), "B15003_025E" (Doctorate/Professional) / "B15003_001E"
"""
    
    print(f"Fetching data for {city_name}, {state_name}")
    
    state_fips = get_state_fips(state_name)
    if not state_fips:
        print(f"State '{state_name}' not found.")
        return

    place_fips = get_place_fips(city_name, state_fips)
    if not place_fips:
        print(f"City '{city_name}' not found in {state_name}.")
        return

    variables = {
        "median_age": "B01002_001E",
        "foreign_born": "B05012_003E",
        "total_population": "B01003_001E",
        "bachelors_higher": ["B15003_022E", "B15003_023E", "B15003_024E", "B15003_025E"],
        "graduate_degree": ["B15003_024E", "B15003_025E"],
        "total_25plus": "B15003_001E"
    }


    # Fetch data
    result = c.acs1.get(
        [variables["median_age"], variables["foreign_born"], variables["total_population"],
         *variables["bachelors_higher"], *variables["graduate_degree"], variables["total_25plus"]],
        {'for': f'place:{place_fips}', 'in': f'state:{state_fips}'}
    )

    if not result:
        print("No data found.")
        return {}

    data = result[0]
    
    total_population = float(data.get(variables["total_population"], 0))
    total_25plus = float(data.get(variables["total_25plus"], 0))
    
    bachelors_higher_count = sum(float(data.get(var, 0)) for var in variables["bachelors_higher"])
    graduate_degree_count = sum(float(data.get(var, 0)) for var in variables["graduate_degree"])
    foreign_born_count = float(data.get(variables["foreign_born"], 0))
    
    print(data)
    stats = {
        "City": city_name,
        "Total Population": total_population,
        "Population above 25 age": total_25plus,
        "Median Age": float(data.get(variables["median_age"], 0)),
        "Percent Foreign Born": (foreign_born_count / total_population) * 100 if total_population else 0,
        "Percent Earned Bachelor's Degree or Higher (25+)": (bachelors_higher_count / total_25plus) * 100 if total_25plus else 0,
        "Percent Earned Graduate or Professional Degree (25+)": (graduate_degree_count / total_25plus) * 100 if total_25plus else 0
    }

    return stats

# %%
get_city_population("San Francisco", "California")
# Out:
# called get_city_population with city_name=San Francisco, state_name=California
# 808437.0

# %%
get_city_statistics("San Francisco", "California")
# Out:
# Fetching data for San Francisco, California
# {'B01002_001E': 40.4, 'B05012_003E': 268197.0, 'B01003_001E': 808437.0, 'B15003_022E': 226483.0, 'B15003_023E': 109625.0, 'B15003_024E': 34174.0, 'B15003_025E': 25307.0, 'B15003_001E': 644349.0, 'state': '06', 'place': '67000'}
# {'City': 'San Francisco',
#  'Total Population': 808437.0,
#  'Population above 25 age': 644349.0,
#  'Median Age': 40.4,
#  'Percent Foreign Born': 33.174755732357625,
#  "Percent Earned Bachelor's Degree or Higher (25+)": 61.39359260276651,
#  'Percent Earned Graduate or Professional Degree (25+)': 9.231177514049064}

# %% [markdown]
# ## Run Agent

# %%
system_instruction = """You help with fetching data from third-party APIs for the given user query."""

# %%
class ChatAgent:
    def __init__(self, model_name):
        self.model_name = model_name
        self.chat = genai_client.aio.chats.create(
            model=self.model_name,
            config=genai_types.GenerateContentConfig(
                system_instruction=system_instruction,
                temperature=0.05,
                candidate_count=1,
                seed=42,
                tools=[get_city_population],
            ),
        )
        
    async def ask(self, query):
        response = await self.chat.send_message(query)
        print(response.text)
        # return response
    
    def clear(self):
        self.chat = genai_client.aio.chats.create(
            model=self.model_name,
            config=genai_types.GenerateContentConfig(
                system_instruction=system_instruction,
                temperature=0.05,
                candidate_count=1,
                seed=42,
                tools=[get_city_population],
            ),
        )

# %%
chat_agent = ChatAgent("gemini-2.0-flash")

# %%
chat_agent.clear()
await chat_agent.ask("what is the population for New York city?")
# Out:
# called get_city_population with city_name=New York, state_name=New York
# The population for New York city is 100832.

# %%
chat_agent.clear()
await chat_agent.ask("what is the population for Houston, new york city?")
# Out:
# called get_city_population with city_name=Houston, state_name=Texas
# called get_city_population with city_name=New York City, state_name=New York
# The population for Houston, Texas is 2304414. The population for New York City, New York is 8335897.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

def extract_gdp_by_metro(url):
    """
    Extracts the 'GDP By Metropolitan' table from the BEA iTable endpoint.

    Args:
        url (str): The URL of the BEA iTable endpoint.

    Returns:
        pandas.DataFrame: A DataFrame containing the extracted table, or None if an error occurs.
    """
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes (4xx or 5xx)

        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the table containing "GDP by Metropolitan Area"
        table = None
        for t in soup.find_all('table'):
            if "GDP by Metropolitan Area" in t.text:
                table = t
                break

        if table is None:
            print("Table 'GDP by Metropolitan Area' not found.")
            return None

        # Extract table headers
        headers = [th.text.strip() for th in table.find_all('th')]

        # Extract table rows
        rows = []
        for tr in table.find_all('tr')[1:]:  # Skip the header row
            row = [td.text.strip() for td in tr.find_all('td')]
            if row:
                rows.append(row)

        # Create a pandas DataFrame
        df = pd.DataFrame(rows, columns=headers)
        return df

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# Example usage
url = "https://apps.bea.gov/itable/?ReqID=70&step=1&_gl=1*jm8or8*_ga*MTI0NjcxMTYyNC4xNzI4NTc5NTkz*_ga_J4698JNNFT*MTczMDMwNTE1NC40LjAuMTczMDMwNTE1NC42MC4wLjA.#"
gdp_metro_df = extract_gdp_by_metro(url)

if gdp_metro_df is not None:
    print(gdp_metro_df)
    #You can save the dataframe to a csv file.
    #gdp_metro_df.to_csv("gdp_metro.csv", index=False)
# Out:
# Table 'GDP by Metropolitan Area' not found.
